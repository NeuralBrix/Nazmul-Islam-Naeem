# %%
import pandas as pd

# %%
df = pd.read_csv("data_set/property_listing_my1st.csv")

# %%
df
# Out:
#                                                   title beds bath        area  \
# 0     Eminent Apartment Of 2200 Sq Ft Is Vacant For ...   3    4   2,200 sqft
# 1     Apartment Ready To Rent In South Khulshi, Near...   3    4   1,400 sqft
# 2     Smartly priced 1950 SQ FT apartment, that you ...   3    4   1,950 sqft
# 3     2000 Sq Ft Residential Apartment Is Up For Ren...   3    3   2,000 sqft
# 4     Strongly Structured This 1650 Sq. ft Apartment...   3    4   1,650 sqft
# ...                                                 ...  ...  ...         ...
# 7552  Picture Yourself, Residing In This Well Constr...   4    4   3,600 sqft
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...   3    2     900 sqft
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...   2    2   1,000 sqft
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...   3    4   3,600 sqft
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
# ...

# %%
#print frist 5 rows
#df.head()

df.head() #by default 5 rows show korbe
# Out:
#                                                title beds bath        area  \
# 0  Eminent Apartment Of 2200 Sq Ft Is Vacant For ...   3    4   2,200 sqft
# 1  Apartment Ready To Rent In South Khulshi, Near...   3    4   1,400 sqft
# 2  Smartly priced 1950 SQ FT apartment, that you ...   3    4   1,950 sqft
# 3  2000 Sq Ft Residential Apartment Is Up For Ren...   3    3   2,000 sqft
# 4  Strongly Structured This 1650 Sq. ft Apartment...   3    4   1,650 sqft
#
#                                adress       type   purpose  \
# 0     Block A, Bashundhara R-A, Dhaka  Apartment  For Rent
# 1  South Khulshi, Khulshi, Chattogram  Apartment  For Rent
# 2     Block F, Bashundhara R-A, Dhaka  Apartment  For Rent
# 3             Sector 9, Uttara, Dhaka  Apartment  For Rent
# 4     Block I, Bashundhara R-A, Dhaka  Apartment  For Rent
#
#                                             flooPlan  \
# 0  https://images-cdn.bproperty.com/thumbnails/10...
# ...

# %%
#print header but just 2/3 rows
#df.head(3)

df.head(2) #2 rows show korbe
# Out:
#                                                title beds bath        area  \
# 0  Eminent Apartment Of 2200 Sq Ft Is Vacant For ...   3    4   2,200 sqft
# 1  Apartment Ready To Rent In South Khulshi, Near...   3    4   1,400 sqft
#
#                                adress       type   purpose  \
# 0     Block A, Bashundhara R-A, Dhaka  Apartment  For Rent
# 1  South Khulshi, Khulshi, Chattogram  Apartment  For Rent
#
#                                             flooPlan  \
# 0  https://images-cdn.bproperty.com/thumbnails/10...
# 1  https://images-cdn.bproperty.com/thumbnails/44...
#
#                                                  url       lastUpdated  \
# 0  https://www.bproperty.com/en/property/details-...   August 13, 2022
# 1  https://www.bproperty.com/en/property/details-...  January 25, 2022
#
#          price
# 0  50 Thousand
# 1  30 Thousand

# %%
#print last 5 rows
#df.tail()

df.tail() #by default 5 rows show korbe
# Out:
#                                                   title beds bath        area  \
# 7552  Picture Yourself, Residing In This Well Constr...   4    4   3,600 sqft
# 7553  Flat For Rent In Uttara Sector 13 Near Lubana ...   3    2     900 sqft
# 7554  1000 SQ FT flat for rent in Uttara Sector 13 n...   2    2   1,000 sqft
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...   3    4   3,600 sqft
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
#                          adress       type   purpose  \
# 7552    Sector 3, Uttara, Dhaka     Duplex  For Rent
# 7553   Sector 13, Uttara, Dhaka  Apartment  For Rent
# 7554   Sector 13, Uttara, Dhaka  Apartment  For Rent
# 7555  Gulshan 1, Gulshan, Dhaka  Apartment  For Rent
# 7556      Baridhara DOHS, Dhaka  Apartment  For Rent
#
#                                                flooPlan  \
# 7552  https://images-cdn.bproperty.com/thumbnails/15...
# 7553  https://images-cdn.bproperty.com/thumbnails/15...
# ...

# %%
#print just 2 rows from bottom
#df.tail(2)

df.tail(2) #2 rows show korbe
# Out:
#                                                   title beds bath        area  \
# 7555  Well Planned Apartment For Rent In Gulshan 1 N...   3    4   3,600 sqft
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
#                          adress       type   purpose  \
# 7555  Gulshan 1, Gulshan, Dhaka  Apartment  For Rent
# 7556      Baridhara DOHS, Dhaka  Apartment  For Rent
#
#                                                flooPlan  \
# 7555  https://images-cdn.bproperty.com/thumbnails/30...
# 7556  https://images-cdn.bproperty.com/thumbnails/15...
#
#                                                     url        lastUpdated  \
# 7555  https://www.bproperty.com/en/property/details-...   February 7, 2023
# 7556  https://www.bproperty.com/en/property/details-...  November 22, 2021
#
#             price
# 7555    1.75 Lakh
# 7556  90 Thousand

# %%
#print midele 5 rows
#df[5:10]

df[4:6]
# Out:
#                                                title beds bath        area  \
# 4  Strongly Structured This 1650 Sq. ft Apartment...   3    4   1,650 sqft
# 5  A nice residential flat of 3400 SQ FT, for ren...   5    5   3,400 sqft
#
#                             adress       type   purpose  \
# 4  Block I, Bashundhara R-A, Dhaka  Apartment  For Rent
# 5        Gulshan 1, Gulshan, Dhaka  Apartment  For Rent
#
#                                             flooPlan  \
# 4  https://images-cdn.bproperty.com/thumbnails/10...
# 5  https://images-cdn.bproperty.com/thumbnails/15...
#
#                                                  url        lastUpdated  \
# 4  https://www.bproperty.com/en/property/details-...  February 19, 2023
# 5  https://www.bproperty.com/en/property/details-...  February 14, 2023
#
#          price
# 4  25 Thousand
# 5     1.1 Lakh

# %%
#all table er info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        7557 non-null   object
#  1   beds         7557 non-null   object
#  2   bath         7557 non-null   object
#  3   area         7557 non-null   object
#  4   adress       7557 non-null   object
#  5   type         7557 non-null   object
#  6   purpose      7557 non-null   object
#  7   flooPlan     7556 non-null   object
#  8   url          7557 non-null   object
#  9   lastUpdated  7557 non-null   object
#  10  price        7557 non-null   object
# dtypes: object(11)
# memory usage: 649.6+ KB

# %%
df [7556 : 7560]
# Out:
#                                                   title beds bath        area  \
# 7556  An Apartment Is Ready For Rent At Baridhara DO...   4    4   2,600 sqft
#
#                      adress       type   purpose  \
# 7556  Baridhara DOHS, Dhaka  Apartment  For Rent
#
#                                                flooPlan  \
# 7556  https://images-cdn.bproperty.com/thumbnails/15...
#
#                                                     url        lastUpdated  \
# 7556  https://www.bproperty.com/en/property/details-...  November 22, 2021
#
#             price
# 7556  90 Thousand

# %%
#print data shape 
df.shape
# Out:
# (7557, 11)

# %%
#print cloumn names
df.columns
# Out:
# Index(['title', 'beds', 'bath', 'area', 'adress', 'type', 'purpose',
#        'flooPlan', 'url', 'lastUpdated', 'price'],
#       dtype='object')

# %%
#just print a specific column
df['price']
# Out:
# 0       50 Thousand
# 1       30 Thousand
# 2       30 Thousand
# 3       35 Thousand
# 4       25 Thousand
#            ...
# 7552    80 Thousand
# 7553    19 Thousand
# 7554    22 Thousand
# 7555      1.75 Lakh
# 7556    90 Thousand
# Name: price, Length: 7557, dtype: object

# %%
#just print a specific column but 1st 5 rows
df['price'].head()
# Out:
# 0    50 Thousand
# 1    30 Thousand
# 2    30 Thousand
# 3    35 Thousand
# 4    25 Thousand
# Name: price, dtype: object

# %%
#just print a specific column but last 5 rows
df['price'].tail(2)
# Out:
# 7555      1.75 Lakh
# 7556    90 Thousand
# Name: price, dtype: object

# %%
#just print a specific two columns
#just print a specific two columns
df[['price', 'adress']].head(2)
# Out:
#          price                              adress
# 0  50 Thousand     Block A, Bashundhara R-A, Dhaka
# 1  30 Thousand  South Khulshi, Khulshi, Chattogram

# %%
#just print a specific 4 column
df[['price', 'adress', 'beds', 'bath']].head(2)
# Out:
#          price                              adress beds bath
# 0  50 Thousand     Block A, Bashundhara R-A, Dhaka   3    4
# 1  30 Thousand  South Khulshi, Khulshi, Chattogram   3    4
